# %%
import os
import numpy as np
import pandas as pd


# DATA = os.path.join(os.path.dirname(os.path.abspath(__file__)), "..", "수업용데이터")   # data/수업용데이터/
df = pd.read_csv("/Users/zoy/Documents/GitHub/deeplearning-pracitce/수업용데이터/11_설비센서_ai4i.csv", encoding="utf-8-sig")

x = df["공기온도"].values.astype(float)    # 입력: 설비 200대의 공기온도. astype(float) = 전부 실수형으로 (정수 섞임 방지)
y = df["공정온도"].values.astype(float)    # 정답: 그 설비의 공정온도
print("설비", len(x), "대 / 공기온도", x.min(), "~", x.max(), "/ 공정온도", y.min(), "~", y.max())
print("앞 5대  공기온도:", x[:5])
print("앞 5대  공정온도:", y[:5])
# Out:
# 설비 200 대 / 공기온도 295.9 ~ 306.1 / 공정온도 304.4 ~ 316.9
# 앞 5대  공기온도: [302.1 299.9 299.9 298.8 300.2]
# 앞 5대  공정온도: [313.2 310.6 310.9 308.8 311. ]
